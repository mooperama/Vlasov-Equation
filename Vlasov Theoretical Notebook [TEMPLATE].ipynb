# %% [markdown]
# # [TOPIC TITLE]: [Subtitle — e.g. Kinetic Description of the System]
# ### [Course Code] — [Course Name] | Theory Notebook
# #### Memebers: [Names]
#
# ---
#
# > **Abstract.** Lorem ipsum dolor sit amet, consectetur adipiscing elit. [Sentence 1: What system is studied and what theoretical framework is developed.] [Sentence 2: What first-principles starting point is used and what reduction is performed.] [Sentence 3: What the central physical prediction is.]
#
# **References:**
# - [Author, *Title*. Publisher, Year. Ch. X.]
# - [Author, *Title*. Publisher, Year. Ch. Y.]
# - [Author (Year). Title. *Journal* **Vol**, page.]
# - [Author (Year). Title. *Journal* **Vol**, page.]
#
# ---
#
# ## Contents
#
# 0. [[Section 0 — Define the medium / physical context]](#0)
# 1. [[Section 1 — Introduce the fundamental statistical object]](#1)
# 2. [[Section 2 — First-principles microscopic reduction]](#2)
# 3. [[Section 3 — Key geometric / conservation theorem]](#3)
# 4. [[Section 4 — Self-consistent governing system]](#4)
# 5. [[Section 5 — Linearisation]](#5)
# 6. [[Section 6 — Derive the central physical phenomenon]](#6)
# 7. [[Section 7 — Bridge to numerical simulation]](#7)

# %%
# ── Dependencies ───────────────────────────────────────────────────────────────
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# from scipy.special import ...    # add as needed
# from scipy.optimize import ...   # add as needed
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.dpi': 130,
    'font.family': 'serif',
    'mathtext.fontset': 'cm',
    'axes.labelsize': 12,
    'axes.titlesize': 13,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
})

# ── Physical constants ─────────────────────────────────────────────────────────
# CONST_A = ...    # [description, SI units]
# CONST_B = ...    # [description, SI units]

# ── Helper functions ───────────────────────────────────────────────────────────
# def my_function(args):
#     """Docstring: what it computes, parameters, returns."""
#     ...

print("Environment ready.")

# %% [markdown]
# ---
# <a id='0'></a>
# ## 0. [Section 0 Title — e.g. The Fourth State: Defining the Medium]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. [Paragraph 1: Describe the physical medium in 2–3 sentences. What is it made of? What distinguishes it from simpler systems? What is the dominant interaction mechanism?]
#
# Sed ut perspiciatis, unde omnis iste natus error sit voluptatem accusantium doloremque laudantium. [Paragraph 2: Contrast with simpler cases. E.g., how does this medium differ from a neutral gas, a crystal, or an ideal fluid?]
#
# > **Analogy.** [State one vivid, concrete analogy that captures the essential physics. One paragraph, in plain language. This is where you earn the Prose Elegance marks.]
#
# ### Why [Specific Condition] is Required
#
# [Explain why the simulation requires a specific version of the medium — e.g. neutral, uniform, unmagnetised. Derive the consequence physically.]
#
# $$[\text{Defining equation for the condition, e.g. charge neutrality}] \tag{0.1}$$
#
# [Explain what goes wrong if the condition is violated — this justifies the choice.]
#
# ### The Validity Parameter: Entrance Condition for the Theory
#
# The central dimensionless parameter governing the validity of the approach is:
#
# $$\boxed{[\Lambda = \ldots \gg 1 \text{ or equivalent}]} \tag{0.2}$$
#
# **Variable anatomy:**
# - $[\Lambda]$ — [name, units]. [What it represents physically.]
# - $[n]$ — [name, units]. [Physical meaning.]
# - $[\lambda]$ — [name, units, definition]. [Physical meaning — e.g. screening length.]
#
# **Provenance.** [Derive or cite where this condition comes from — e.g. ratio of collective to binary interaction energy.]
#
# **Intuition.** [One sentence on what the inequality means for a representative particle in the system.]

# %%
# ── Figure 0: Validity parameter across parameter space ───────────────────────
# GOAL: Show where the theory is valid in a 2-D parameter space (e.g. n vs T).
# Shade the valid region; mark representative physical systems.

# %% [markdown]
# ---
# <a id='1'></a>
# ## 1. [Section 1 Title — e.g. Mapping the Mist: The Statistical Object]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Explain why a single-particle description is intractable and what statistical object replaces it. 2–3 sentences of prose.]
#
# > **Analogy.** [Vivid analogy for the statistical object — e.g. airport density map, weather forecast grid.]
#
# ### The [Distribution Function / Field / Density Matrix]
#
# The **[name of fundamental object]** $f(\mathbf{r}, \mathbf{v}, t)$ is defined such that
#
# $$\boxed{dN = f(\mathbf{r}, \mathbf{v}, t)\, d^3\mathbf{r}\, d^3\mathbf{v}} \tag{1.1}$$
#
# [Sentence: state what $dN$ represents.]
#
# **Variable anatomy:**
# - $f(\mathbf{r}, \mathbf{v}, t)$ — [name, units]. [Physical meaning.]
# - $\mathbf{r}$ — [name, units]. [Physical meaning.]
# - $\mathbf{v}$ — [name, units]. [Physical meaning.]
# - $t$ — [name, units].
# - $d^3\mathbf{r}\,d^3\mathbf{v}$ — [name, units]. [Physical meaning.]
#
# **Provenance.** [Where does this definition come from — continuum limit, ensemble average, etc.?]
#
# **Conceptual subtlety.** [Note any non-obvious feature — e.g. independent vs. dependent variables, difference from Newtonian picture.]
#
# ### Macroscopic Moments
#
# [Explain that observables are obtained as integrals / moments of $f$.]
#
# | Moment | Expression | Observable |
# |--------|-----------|------------|
# | [name] | $[\int f\,d^3v]$ | [name, units] |
# | [name] | $[\int \mathbf{v}f\,d^3v]$ | [name, units] |
# | [name] | $[\frac{m}{2}\int v^2 f\,d^3v]$ | [name, units] |
#
# [One sentence: why the kinetic description contains more information than any fluid / macroscopic model.]

# %%
#Code Here

# %% [markdown]
# ---
# <a id='2'></a>
# ## 2. [Section 2 Title — e.g. From Klimontovich to Vlasov: First-Principles Reduction]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Describe the exact microscopic description — the starting point before any averaging or reduction. Why is it exact but intractable?]
#
# > **Analogy.** [Analogy for the zoom-in/zoom-out operation — e.g. pixels vs photograph, atoms vs fluid.]
#
# ### 2.1 The Exact Microscopic Description
#
# [Name and state the exact equation or distribution. E.g. Klimontovich, Liouville, Schrödinger.]
#
# $$[N_\alpha(\mathbf{x}, \mathbf{v}, t) = \sum_{k} \delta[\ldots]] \tag{2.1}$$
#
# **Variable anatomy:**
# - $[N_\alpha]$ — [name, units]. [Physical meaning.]
# - $[\delta]$ — [Dirac delta or equivalent, units]. [Physical meaning.]
# - $[\mathbf{x}_k(t), \mathbf{v}_k(t)]$ — [name, units]. [Physical meaning.]
#
# **Provenance.** [Briefly how this equation is derived — Newton's law + chain rule, or equivalent.]
#
# ### 2.2 The Averaging / Reduction Procedure
#
# [State what operation is applied to reduce the exact description — ensemble average, coarse-graining, thermodynamic limit.]
#
# $$f \equiv \langle N_\alpha \rangle, \qquad [\text{remaining equation after averaging}] \tag{2.2}$$
#
# [Identify the term that is neglected — e.g. two-body correlations, fluctuation product. State why it is small.]
#
# ### 2.3 The Mean-Field Limit and Validity
#
# [State the approximation that closes the reduced equation. State the dimensionless condition under which it is accurate.]
#
# [Closing sentence: what physical information is retained and what is discarded in the reduction.]

# %%
# ── Figure 2: Microscopic → smooth: convergence as N → ∞ ─────────────────────
# GOAL: Show three histograms/scatter plots with increasing N,
#       converging to the smooth equilibrium distribution.

# %% [markdown]
# ---
# <a id='3'></a>
# ## 3. [Section 3 Title — e.g. The Geometry of Flow: Liouville's Theorem]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Describe the geometric / conservation content of this section in non-mathematical terms. What is incompressible? What is preserved? 2–3 sentences.]
#
# > **Analogy.** [Water-bag or equivalent analogy for phase-space incompressibility. Make it vivid.]
#
# ### 3.1 The 6D Continuity Equation
#
# [Set up the continuity equation for the phase-space fluid. Define the 6D velocity vector.]
#
# $$\mathbf{w} = (\dot{\mathbf{x}},\, \dot{\mathbf{v}}) = \left(\mathbf{v},\, \frac{\mathbf{F}}{m}\right). \tag{3.1}$$
#
# **Variable anatomy:**
# - $\mathbf{w}$ — [name, units]. [Physical meaning.]
# - $\mathbf{F}$ — [name, units]. [The specific force relevant to your system.]
# - $m$ — [name, units].
#
# [Apply the divergence theorem to obtain the 6D continuity equation.]
#
# $$\frac{\partial f}{\partial t} + \nabla_{\mathbf{x}}\cdot(\mathbf{v}\,f) + \nabla_{\mathbf{v}}\cdot\!\left(\frac{\mathbf{F}}{m}\,f\right) = 0. \tag{3.2}$$
#
# ### 3.2 Liouville's Theorem: Proof of Incompressibility
#
# **Theorem.** [State the theorem precisely. The phase-space velocity field satisfies:]
#
# $$\nabla_{\mathbf{x}}\cdot\mathbf{v} + \nabla_{\mathbf{v}}\cdot\frac{\mathbf{F}}{m} = 0. \tag{3.3}$$
#
# **Proof.**
#
# *Part 1:* $\nabla_{\mathbf{x}}\cdot\mathbf{v} = 0$ because [reason — independence of coordinates].
#
# *Part 2:* For $\mathbf{F} = [\text{your specific force}]$:
#
# $$\nabla_{\mathbf{v}}\cdot\mathbf{F} = [\text{expand}] \tag{3.4}$$
#
# $$= [\text{apply vector identity: name it}] \tag{3.5}$$
#
# $$= 0. \quad \square \tag{3.6}$$
#
# ### 3.3 The Central Equation
#
# [Using incompressibility, simplify (3.2) to obtain the central kinetic equation.]
#
# $$\boxed{[\text{CENTRAL EQUATION}]} \tag{3.7}$$
#
# ### 3.4 Characteristic Form: $df/dt = 0$ Along Orbits
#
# [Rewrite the equation as a total time derivative along particle trajectories.]
#
# $$\frac{df}{dt}\bigg|_{\text{orbit}} = 0. \tag{3.8}$$
#
# [Interpretation: what does this mean physically — water-bag, memory, reversibility.]
#
# ### 3.5 Consequences: Conserved Quantities
#
# [State the invariants that follow from (3.8) — Casimir invariants, entropy conservation.]
#
# $$S = -\int f\ln f\,d^6z = \mathrm{const.} \tag{3.9}$$
#
# [Contrast with the collisional case where $S$ increases monotonically.]

# %%
# ── Figure 3: Liouville — area-preserving phase-space deformation ──────────────
# GOAL: Evolve a blob of N_p particles under your system's equations of motion.
#       Show 4 snapshots; compute and display the blob area to verify conservation.

# %% [markdown]
# ---
# <a id='4'></a>
# ## 4. [Section 4 Title — e.g. The Self-Consistent Loop: The Governing System]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Explain why the kinetic equation alone is incomplete. What additional field equation or coupling is required? 2 sentences.]
#
# > **Analogy.** [Flash-mob or feedback-loop analogy — dancers create music which dictates the dance.]
#
# ### 4.1 The Coupled System
#
# [Write the complete coupled system: kinetic equation + field equation.]
#
# $$[\text{Kinetic equation}] \tag{4.1}$$
#
# $$[\text{Field equation — e.g. Poisson, Maxwell, Schrödinger}] \tag{4.2}$$
#
# $$[\text{Field definition — e.g. } \mathbf{E} = -\nabla\phi] \tag{4.3}$$
#
# **Variable anatomy:**
# - $[\phi]$ — [name, units]. [Physical meaning.]
# - $[\mathbf{E}]$ — [name, units]. [Physical meaning.]
# - $[n_0]$ — [name, units]. [Physical meaning — e.g. neutralising background.]
# - $[\int f\,d^3v]$ — [name, units]. [Physical meaning — zeroth moment.]
#
# **Provenance.** [Name the physical law the field equation comes from — Gauss, Maxwell, etc.]
#
# **The self-consistent loop:**
# 1. $f \xrightarrow{\int d^3v} [\text{density}]$ — [describe step.]
# 2. $[\text{density}] \xrightarrow{\text{field equation}} [\text{field}]$ — [describe step.]
# 3. $[\text{field}] \xrightarrow{\text{kinetic eq.}} f$ — [describe step.]
# 4. Return to step 1.
#
# **Important limit.** ([Condition, e.g. electrostatic, non-relativistic]): [Describe simplification.]
#
# $$[\text{Simplified field equation in this limit}] \tag{4.4}$$
#
# > **Assumptions of this section:**
# > - [Assumption 1 — e.g. non-relativistic: $v \ll c$]
# > - [Assumption 2 — e.g. no magnetic perturbations]
# > - [Assumption 3 — e.g. fixed ion background]

# %%
# ── Figure 4: Schematic of the self-consistent loop ───────────────────────────
# GOAL: Draw a flowchart-style diagram of the feedback loop using matplotlib text/arrows.
# No external libraries needed — just ax.text and ax.annotate.

# %% [markdown]
# ---
# <a id='5'></a>
# ## 5. [Section 5 Title — e.g. The Plasma Shiver: Linearisation for Waves]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Explain why the full nonlinear system must be linearised for wave analysis. What is the small parameter? 2–3 sentences.]
#
# > **Analogy.** [Guitar string / quiet lake / pendulum analogy — equilibrium, small perturbation, natural modes.]
#
# ### 5.1 The Perturbation Ansatz
#
# [Decompose $f$ and the field into equilibrium + perturbation.]
#
# $$f = f_0(\mathbf{v}) + f_1(\mathbf{x}, \mathbf{v}, t), \quad |f_1| \ll f_0. \tag{5.1}$$
#
# $$\phi = 0 + \phi_1(\mathbf{x}, t). \tag{5.2}$$
#
# **Variable anatomy:**
# - $f_0(\mathbf{v})$ — [name, units]. [What makes it an equilibrium — spatially uniform, time-independent.]
# - $f_1$ — [name, units]. [Size constraint: $\|f_1\| / \|f_0\| \sim \epsilon \ll 1$.]
# - $\phi_1$ — [name, units]. [Why $\phi_0 = 0$ — neutrality condition.]
#
# **Why $\phi_0 = 0$?** [Derive from neutrality: $n_e = n_0 \Rightarrow \nabla^2\phi_0 = 0 \Rightarrow \phi_0 = 0$.]
#
# ### 5.2 Derivation of the Linearised Kinetic Equation
#
# [Substitute (5.1)–(5.2) into the coupled system. Show which terms are zero and which are dropped as second-order.]
#
# $$[\text{Full equation after substitution}] \tag{5.3}$$
#
# [Name the second-order term that is dropped and why.]
#
# $$\boxed{[\text{LINEARISED KINETIC EQUATION}]} \tag{5.4}$$
#
# $$[\text{Linearised field equation}] \tag{5.5}$$
#
# **Structural observation.** [Note which term couples the wave to the equilibrium — e.g. $\nabla\phi_1\cdot\nabla_\mathbf{v}f_0$. This is the physical coupling mechanism.]
#
# ### 5.3 Normal Mode Analysis
#
# [State the plane-wave ansatz.]
#
# $$f_1 \propto e^{i(kx - \omega t)}, \qquad \phi_1 \propto e^{i(kx - \omega t)}. \tag{5.6}$$
#
# **Variable anatomy:**
# - $k$ — [name, units]. [Relation to wavelength.]
# - $\omega$ — [name, units, complex]. [Real part: oscillation rate. Imaginary part: growth/decay rate.]
#
# [Substitute into (5.4) and solve for $\hat{f}_1$.]
#
# $$\hat{f}_1(v) = [\text{expression involving } \omega, k, \partial f_0/\partial v] \tag{5.7}$$
#
# [Substitute into the field equation and cancel the amplitude to get the dispersion relation.]
#
# $$\boxed{\varepsilon(k, \omega) \equiv [\text{DISPERSION RELATION}] = 0.} \tag{5.8}$$

# %%
# ── Figure 5: Linearisation — equilibrium, perturbation, and resonance ─────────
# GOAL: Panel 1 — f0 with f1 overlay showing smallness.
#       Panel 2 — df0/dv (the coupling kernel).
#       Panel 3 — 1/(v - v_phi), the resonant denominator.

# %% [markdown]
# ---
# <a id='6'></a>
# ## 6. [Section 6 Title — e.g. The Climax: Langmuir Waves and Landau Damping]
#
# ### The Physical Narrative
#
# Lorem ipsum dolor sit amet. [Describe the wave physically — what causes the restoring force, what provides the inertia, why does it oscillate at a specific frequency? 2–3 sentences.]
#
# > **Analogy.** [Pendulum analogy: gravity ↔ electrostatic restoring force; length ↔ inertia parameter.]
#
# ### 6.1 Resolving the Resonant Denominator: The Landau Prescription
#
# [Explain the initial-value problem motivation. State the Plemelj–Sokhotski identity.]
#
# $$\lim_{\gamma \to 0^+}\int\frac{g(v)}{v - \omega_r/k - i\gamma/k}\,dv
# = \mathcal{P}\int\frac{g(v)}{v - \omega_r/k}\,dv + i\pi\,g\!\left(\frac{\omega_r}{k}\right). \tag{6.1}$$
#
# [Identify $g(v) = \partial f_0/\partial v$.]
#
# ### 6.2 The Real Dispersion Relation
#
# [Evaluate the principal-value integral for your equilibrium $f_0$ in the long-wavelength limit. State the expansion or technique used.]
#
# $$[\text{Result of principal-value integral}] \approx [\text{expansion terms}] \tag{6.2}$$
#
# [Insert into Re$[\varepsilon] = 0$ to obtain:]
#
# $$\boxed{[\omega_r^2 = \omega_0^2(1 + \alpha\, k^2\lambda^2 + \ldots)]} \tag{6.3}$$
#
# **Variable anatomy:**
# - $\omega_r$ — [name, units]. [Physical meaning.]
# - $\omega_0$ — [name, units, definition]. [Physical meaning — zero-temperature limit.]
# - $\alpha$ — [numerical coefficient]. [Where it comes from — thermal correction.]
# - $\lambda$ — [name, units]. [Physical meaning.]
#
# **Interpretation.** [Cold limit: $T \to 0$. Thermal correction: what stiffens the wave.]
#
# ### 6.3 The Imaginary Part: Growth/Damping Rate
#
# [Use the imaginary part of (6.1) to derive the growth/damping rate perturbatively.]
#
# $$\gamma = [\text{expression involving } \partial f_0/\partial v|_{v_\phi}]. \tag{6.4}$$
#
# [Evaluate for your specific $f_0$:]
#
# $$\boxed{\gamma = [\text{FINAL EXPLICIT DAMPING/GROWTH RATE}]} \tag{6.5}$$
#
# ### 6.4 Physical Mechanism
#
# [Explain in physical prose — no equations — who the resonant particles are, what energy transfer occurs, whether the process is reversible. Specifically address when $\gamma < 0$ (damping) and when $\gamma > 0$ (instability).]
#
# **Stability condition:**
# $$[\partial f_0/\partial v|_{v_\phi} \lessgtr 0 \Leftrightarrow \gamma \lessgtr 0.] \tag{6.6}$$

# %%
# ── Figure 6: Dispersion relation and damping/growth rate ─────────────────────
# GOAL: Panel 1 — resonance picture (f0 with v_phi marked).
#       Panel 2 — omega_r(k): numerical vs analytic.
#       Panel 3 — |gamma(k)|: numerical vs analytic on log scale.

# %%
# ── Figure 7: Stable vs unstable — damped vs growing wave ────────────────────
# GOAL: Panel 1 — stable and unstable distributions side by side.
#       Panel 2 — schematic E(t) for both cases.

# %% [markdown]
# ---
# <a id='7'></a>
# ## 7. [Section 7 Title — e.g. Bridging to Code: The Need for Numerical Methods]
#
# ### 7.1 The Limits of Linear Theory
#
# Lorem ipsum dolor sit amet. [When does linearisation break down? State the condition in terms of wave amplitude.]
#
# $$|f_1| \sim f_0 \quad \text{or equivalently} \quad [\text{equivalent amplitude condition}] \tag{7.1}$$
#
# [Name 2–3 nonlinear phenomena that require simulation — e.g. particle trapping, mode coupling, saturation.]
#
# ### 7.2 Choice of Numerical Method
#
# [State which family of methods is appropriate and why. Address the accuracy/noise tradeoff.]
#
# **[Method A — e.g. Particle-in-Cell]:** [Description. Strength: efficiency. Weakness: statistical noise $\sim 1/\sqrt{N_p}$.]
#
# **[Method B — e.g. Semi-Lagrangian]:** [Description. Strength: no noise. Uses characteristic form:]
#
# $$f^{n+1}(x_i, v_j) = f^n\!\left(x_i - v_j\Delta t,\; v_j - \frac{[F]}{m}\Delta t\right) \tag{7.2}$$
#
# [Conclude which method is preferred for your problem and why.]
#
# ### 7.3 Conservation as Sanity Checks
#
# [State the global conservation laws that every valid numerical scheme must satisfy.]
#
# $$N = \int\!\int f\,dx\,dv = \mathrm{const.} \tag{7.3}$$
#
# $$W = [\text{kinetic energy}] + [\text{field energy}] = \mathrm{const.} \tag{7.4}$$
#
# [Explain why these are necessary but not sufficient checks — add Casimir invariants.]
#
# ### 7.4 Summary: Theory–Simulation Connection
#
# | Theoretical result | Role in simulation |
# |--------------------|-------------------|
# | [Section 0 result] | [Role in code] |
# | [Section 1 result] | [Role in code] |
# | [Section 3 result: $df/dt|_{\rm orbit}=0$] | [Basis of advection step] |
# | [Section 6: $\omega_r(k)$] | [Target dispersion to recover] |
# | [Section 6: $\gamma(k)$] | [Target damping rate] |
# | [Conservation laws] | [Sanity checks at every step] |

# %%
# ── Figure 8: Summary — conservation check and section table ──────────────────
# GOAL: Panel 1 — schematic total energy W(t)/W(0) for good vs leaky integrator.
#       Panel 2 — summary table of all sections.
